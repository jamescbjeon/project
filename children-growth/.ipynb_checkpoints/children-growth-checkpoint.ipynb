# %% [markdown]
# # Children growth

# %% [markdown]
# Process engineer라는 업의 특성 때문인지 어떤 특성에 대한 숫자화와 이력 관리에 대한 강박이 있는 편이다. 내 아이들과 조카의 신체 성장 기록을 엑셀 시트로 수 년간 관리했었는데 Pandas skill practice 일환으로 Notebook version으로 migration 해보도록 한다.

# %%
# Improt libraries
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')  # 시각화를 위해 'seaborn-withegrid' 스타일 적용
# plt.rcParams.update({'font.size': 16})

import seaborn as sns
import scipy.stats as ss

# %%
# Children birth infomation for data index, month from birth
birth = {'Ariel': pd.Timestamp('2012-01-28'), \
         'Ted': pd.Timestamp('2013-09-28'), \
         'Jua': pd.Timestamp('2014-11-10')}

# Male = 1, Female = 2
gender_dict = {'Ariel': 2, 'Ted': 1, 'Jua': 2}  

# MONTHS_FROM_BIRTH 열 생성을 위한 apply 적용 시 사용
def month_diff(row):   
    return (row.DATE - birth[row.PERSON]).days // 30

# 소아청소년 성장도표 읽어오기
def read_table_from_excel(sheet):
    col = ['GENDER', 'AGE_YEAR', 'AGE_MONTH', 'L', 'M', 'S', \
       'PER_1', 'PER_3', 'PER_5', 'PER_10', 'PER_15', 'PER_25', 'PER_50', \
       'PER_75', 'PER_85', 'PER_90', 'PER_95','PER_97', 'PER_99', \
       '-3SD', '-2SD', '-1SD', '0SD', '+1SD', '+2SD', '+3SD']
    
    table = pd.read_excel('growth-table.xls', sheet_name= sheet, skiprows= 2, header= None)
    table.columns = col

    table.drop('AGE_YEAR', axis= 1, inplace= True)
    table.set_index('AGE_MONTH', inplace= True)
    
    return table

# %%
df = pd.read_csv('children-growth.csv')

df.DATE = pd.to_datetime(df.DATE)  # Change dtype from string to pandas datetime
df['MONTHS_FROM_BIRTH'] = df.apply(month_diff, axis=1)  # Create new column, months from birth
df['BMI'] = df.WEIGHT / df.HEIGHT / df.HEIGHT * 10000  # Create new column, BMI - Body Mass Index

df.set_index('MONTHS_FROM_BIRTH', inplace=True)
df.sort_index(inplace= True)

df.head()
# Out:
#                   PERSON       DATE  WEIGHT  HEIGHT  HEAD        BMI
# MONTHS_FROM_BIRTH
# 12                   Ted 2014-09-23    11.3    77.3   NaN  18.911216
# 17                   Ted 2015-03-19    12.8    80.8  49.5  19.605921
# 18                   Ted 2015-04-19    12.0    82.0  49.0  17.846520
# 18                   Ted 2015-04-10    13.0    83.0   NaN  18.870663
# 20                   Ted 2015-06-03    13.2    82.0   NaN  19.631172

# %% [markdown]
# 정리된 Dataset 결과이다. raw data의 경우, 대상 (PERSON), 일자 (DATE) 및 측정 결과 - 몸무게 (WEIGHT), 키 (HEIGHT), 머리둘레 (HEAD) - 로 이루어져 있었다. 이를 사전 입력한 출생연도 (birth) dictionary를 이용하여 생후개월 (MONTH_FROM_BIRTH)을 생성 후 Index로 정렬했으며, 추가로 비만 정도를 알 수 있는 Body Mass Index (BMI) 열을 생성하였다.

# %%
df.shape
# Out:
# (77, 6)

# %%
df.dtypes
# Out:
# PERSON            object
# DATE      datetime64[ns]
# WEIGHT           float64
# HEIGHT           float64
# HEAD             float64
# BMI              float64
# dtype: object

# %%
df.describe(include= 'all')
# Out:
#        PERSON                 DATE     WEIGHT      HEIGHT       HEAD  \
# count      77                   77  77.000000   77.000000  43.000000
# unique      3                   46        NaN         NaN        NaN
# top     Ariel  2019-01-09 00:00:00        NaN         NaN        NaN
# freq       37                    3        NaN         NaN        NaN
# first     NaN  2014-06-26 00:00:00        NaN         NaN        NaN
# last      NaN  2020-12-29 00:00:00        NaN         NaN        NaN
# mean      NaN                  NaN  20.315584  106.763636  50.253488
# std       NaN                  NaN   6.372785   14.687570   1.717466
# min       NaN                  NaN  11.300000   77.300000  46.000000
# 25%       NaN                  NaN  16.000000   96.200000  49.250000
# 50%       NaN                  NaN  19.200000  105.500000  50.000000
# 75%       NaN                  NaN  22.200000  116.000000  52.000000
# max       NaN                  NaN  37.100000  136.700000  53.500000
#
#               BMI
# count   77.000000
# unique        NaN
# top           NaN
# freq          NaN
# first         NaN
# last          NaN
# mean    17.444360
# std      1.321455
# min     15.304496
# 25%     16.261027
# 50%     17.464328
# 75%     18.328429
# max     19.853491

# %% [markdown]
# 세 아이들의 생후개월 대비 키 성장을 비교한 값이다. Ariel의 경우, 가장 나이가 많다보니 나머지 두 아이들에 비해 키가 굉장히 크다는 평가를 집안 어른들로부터 많이 받는 편이다. 하지만 데이터 를 비교할 경우, 실제 세 아이들의 키 성장은 생후 70개월까지는 큰 차이가 없이 거의 비슷함을 확인할 수 있다. 오히려 70개월 차부터는 Ted의 키가 갑자기 컸음을 알 수 있다.
#
# 또한 아이들의 키 성장이 생후 100개월 내외까지는 선형 모델과 유사한 것을 추정된다. 예를 들어 아래 Ariel 키 값을 가지고 regression plot을 그려보았을 때 1차 선형모델과 꽤 근사하게 확인된다 (물론 100개월 전후로 1차 선형에서 벗어나려는 모양이 일부 확인되는 듯 하다). 이에 대한 자세한 내용은 대한민국 소아 및 청소년 성장도표와 함께 추가적으로 살펴보도록 하자.

# %%
for person in birth:
    df.loc[df.PERSON == person, 'HEIGHT'].plot(marker='.', figsize= (8, 6))

plt.legend(birth)
plt.xlabel('Months from birth')
plt.ylabel('Kids Height (cm)')
plt.show()

# %%
sns.regplot(data= df.loc[df.PERSON == 'Ariel', :].reset_index(), x= 'MONTHS_FROM_BIRTH', y='HEIGHT')

# %% [markdown]
# 키와 달리 몸무게는 세 아이가 차이를 보인다. Ted의 경우, 남자 아이라서 다른 두 여자 아이에 비해 몸무게가 높은 편이다. 다른 특이점으로는 Ariel의 몸무게가 90개월을 지나는 시점에서 갑자기 크게 증가하였다.

# %%
for person in birth:
    df.loc[df.PERSON == person, 'WEIGHT'].plot(marker='.', figsize= (8, 6))

plt.legend(birth)
plt.xlabel('Months from birth')
plt.ylabel('Kids Weight (kg)')
plt.show()

# %% [markdown]
# 키와 몸무게의 성장은 당연하게 같이 수반되는 것이지만 때로는 키에 비해 몸무게가 과다하거나 부족하여 비만이나 체중미달의 위험에 도달하기도 한다. 이를 확인하는 간단한 지표로 BMI를 사용할 수 있다. Body Mass Index는 몸무게를 키의 제곱값으로 나눈 결과이다.
#
# Ted의 몸무게가 다른 두 여자아이 대비하여 높았지만 BMI는 18~19 내외에서 유지되고 있음을 확인할 수 있다. 오히려, Ariel의 BMI가 최근 16에서 19.5까지 크게 증가하였다. 성장기에 키와 몸무게의 증가는 당연하나 비만의 우려가 있으므로 관리가 필요한 시점임을 알 수 있다.

# %%
for person in birth:
    df.loc[df.PERSON == person, 'BMI'].plot(marker='.', figsize= (8, 6))

plt.legend(birth)
plt.xlabel('Months from birth')
plt.ylabel('Body Mass Index')
plt.show()

# %% [markdown]
# 머리둘레의 경우, 키나 몸무게에 비해 누락데이터가 많은 편이다. 실제 측정해 보니 측정위치가 동일하지 않거나 아이들의 머리 상태(머리숱 및 핀 등을 통한 꾸밈 상태)에 따라 으면 오차가 제법 발생하는 편이었다.
#
# 머리 둘레의 경우, 아래의 결과를 확인했다.
# 1. 키나 몸무게에 비해 머리둘레의 성장은 빠르지 않다. 즉, 초기값이 유지되며 서서히 증가한다.
# 2. 따라서 초기값이 중요하다 (아직 결론 내리기에 데이터가 부족하나 소두와 대두는 어릴 때부터 타고나는 것 같다.)

# %%
for person in birth:
    df.loc[df.PERSON == person, 'HEAD'].dropna(axis= 0).plot(marker='.', figsize= (8, 6))

plt.legend(birth)
plt.xlabel('Months from birth')
plt.ylabel('Head around (cm)')
plt.show()

# %% [markdown]
# 지금까지 세 아이들의 측정결과를 생후개월 대비하여 확인해보았다. 이제 내가 가지고 있는 dataset을 넘어 다른 아이들과의 비교를 통해 우리 아이들의 성장 수준을 확인해 보도록 하자.
#
# 질병관리청에서 소아청소년 성장 수준 통계를 도표로 제공하고 있다 (http://www.cdc.go.kr/contents.es?mid=a20303030400). 이를 지금까지의 데이터와 병기하여 확인해보자.

# %%
height = read_table_from_excel('연령별 신장')
weight = read_table_from_excel('연령별 체중')
bmi = read_table_from_excel('연령별 체질량지수')
head = read_table_from_excel('연령별 머리둘레')

# %%
height.head()
# Out:
#            GENDER    L        M       S  PER_1  PER_3  PER_5  PER_10  PER_15  \
# AGE_MONTH
# 0               1  1.0  49.8842  0.0380   45.5   46.3   46.8    47.5    47.9
# 1               1  1.0  54.7244  0.0356   50.2   51.1   51.5    52.2    52.7
# 2               1  1.0  58.4249  0.0342   53.8   54.7   55.1    55.9    56.4
# 3               1  1.0  61.4292  0.0333   56.7   57.6   58.1    58.8    59.3
# 4               1  1.0  63.8860  0.0326   59.0   60.0   60.5    61.2    61.7
#
#            PER_25  ...  PER_95  PER_97  PER_99  -3SD  -2SD  -1SD   0SD  +1SD  \
# AGE_MONTH          ...
# 0            48.6  ...    53.0    53.4    54.3  44.2  46.1  48.0  49.9  51.8
# 1            53.4  ...    57.9    58.4    59.3  48.9  50.8  52.8  54.7  56.7
# 2            57.1  ...    61.7    62.2    63.1  52.4  54.4  56.4  58.4  60.4
# 3            60.1  ...    64.8    65.3    66.2  55.3  57.3  59.4  61.4  63.5
# 4            62.5  ...    67.3    67.8    68.7  57.6  59.7  61.8  63.9  66.0
#
#            +2SD  +3SD
# AGE_MONTH
# 0          53.7  55.6
# 1          58.6  60.6
# 2          62.4  64.4
# 3          65.5  67.6
# 4          68.0  70.1
#
# [5 rows x 24 columns]

# %%
def growth_comparison_plot(gender, people, table, col_name):
    comparison_col = ['PER_10', 'PER_25', 'PER_50', 'PER_75', 'PER_90']
    
    table.loc[table.GENDER == gender, comparison_col].plot(linestyle= ':')
    for person in people:
        df.loc[df.PERSON == person, col_name].dropna(axis=0).plot(marker='.', figsize= (8, 6))
    
    ylabeldict = {'HEIGHT': 'Height (cm)', 'WEIGHT': 'Weight (kg)', 'BMI': 'Body Mass Index', 'HEAD': 'Head-around (cm)'}
    
    plt.title(col_name)
    plt.legend(people)
    plt.xlabel('Months from birth')
    plt.ylabel(ylabeldict[col_name])
    plt.show()

# %%
growth_comparison_plot(2, ['Ariel', 'Jua'], height, 'HEIGHT')

# %%
growth_comparison_plot(2, ['Ariel', 'Jua'], weight, 'WEIGHT')

# %%
growth_comparison_plot(2, ['Ariel', 'Jua'], bmi, 'BMI')

# %%
growth_comparison_plot(2, ['Ariel', 'Jua'], head, 'HEAD')

# %%
growth_comparison_plot(1, ['Ted'], height, 'HEIGHT')

# %%
growth_comparison_plot(1, ['Ted'], weight, 'WEIGHT')

# %%
growth_comparison_plot(1, ['Ted'], bmi, 'BMI')

# %%
growth_comparison_plot(1, ['Ted'], head, 'HEAD')

# %%
df.tail()
# Out:
#                   PERSON       DATE  WEIGHT  HEIGHT  HEAD        BMI
# MONTHS_FROM_BIRTH
# 104                Ariel 2020-09-08    35.1   134.8   NaN  19.316451
# 105                Ariel 2020-10-06    35.3   134.8   NaN  19.426516
# 106                Ariel 2020-11-03    35.6   135.5   NaN  19.389714
# 107                Ariel 2020-12-01    36.1   136.1   NaN  19.489063
# 108                Ariel 2020-12-29    37.1   136.7   NaN  19.853491

# %%
height.loc[(height.GENDER == 1) & (height.index == 108), :].L.values
# Out:
# array([0.1885])

# %%
Z = (((x / M) ** L) - 1) / (L * S)
# Out:
# 8

# %%
latest_index_dict
# Out:
# {'Ariel': 108, 'Ted': 79, 'Jua': 62}

# %%
df.head()
# Out:
#                   PERSON       DATE  WEIGHT  HEIGHT  HEAD        BMI
# MONTHS_FROM_BIRTH
# 12                   Ted 2014-09-23    11.3    77.3   NaN  18.911216
# 17                   Ted 2015-03-19    12.8    80.8  49.5  19.605921
# 18                   Ted 2015-04-19    12.0    82.0  49.0  17.846520
# 18                   Ted 2015-04-10    13.0    83.0   NaN  18.870663
# 20                   Ted 2015-06-03    13.2    82.0   NaN  19.631172

# %%
gender_dict
# Out:
# {'Ariel': 2, 'Ted': 1, 'Jua': 2}

# %%
def test(row, item):
    x = df.loc[row, item]
    
    return x

# %%
def find_percentile(row, item):

    x = row.loc[(df.PERSON == person), col_name]
    l = table.loc[(table.index == latest_index_dict[person]) & (table.GENDER == gender_dict[person]), :].L
    m = table.loc[(table.index == latest_index_dict[person]) & (table.GENDER == gender_dict[person]), :].M
    s = table.loc[(table.index == latest_index_dict[person]) & (table.GENDER == gender_dict[person]), :].S
    
    
    latest_index_dict = {}

    row.PERSON
    for person in birth:
        latest_index_dict[person] = df.loc[df.PERSON == person, :].tail(1).index[0]

    for person in latest_index_dict:


        Z = ((x / m) ** l - 1) / (l * s)

        percentile = ss.norm.cdf(Z) * 100

        print('{}: {:.0f}th'.format(person, percentile[0]))

# %%
def find_percentile(table, col_name):
    latest_index_dict = {}

    for person in birth:
        latest_index_dict[person] = df.loc[df.PERSON == person, :].tail(1).index[0]

    for person in latest_index_dict:
        x = df.loc[(df.index == latest_index_dict[person]) & (df.PERSON == person), col_name]
        l = table.loc[(table.index == latest_index_dict[person]) & (table.GENDER == gender_dict[person]), :].L
        m = table.loc[(table.index == latest_index_dict[person]) & (table.GENDER == gender_dict[person]), :].M
        s = table.loc[(table.index == latest_index_dict[person]) & (table.GENDER == gender_dict[person]), :].S

        Z = ((x / m) ** l - 1) / (l * s)

        percentile = ss.norm.cdf(Z) * 100

        print('{}: {:.0f}th'.format(person, percentile[0]))

# %%
find_percentile(height, 'HEIGHT')
# Out:
# Ariel: 76th
# Ted: 50th
# Jua: 41th

# %%
find_percentile(weight, 'WEIGHT')
# Out:
# Ariel: 87th
# Ted: 87th
# Jua: 74th

# %%
find_percentile(bmi, 'BMI')
# Out:
# Ariel: 86th
# Ted: 94th
# Jua: 85th

# %%
L/M
# Out:
# AGE_MONTH
# 108    0.001413
# dtype: float64

# %%
str(weight)
# Out:
# '           GENDER       L        M       S  PER_1  PER_3  PER_5  PER_10  \\\nAGE_MONTH                                                                 \n0               1  0.3487   3.3464  0.1460    2.3    2.5    2.6     2.8   \n1               1  0.2297   4.4709  0.1340    3.2    3.4    3.6     3.8   \n2               1  0.1970   5.5675  0.1239    4.1    4.4    4.5     4.7   \n3               1  0.1738   6.3762  0.1173    4.8    5.1    5.2     5.5   \n4               1  0.1553   7.0023  0.1132    5.4    5.6    5.8     6.0   \n...           ...     ...      ...     ...    ...    ...    ...     ...   \n223             2 -0.7497  53.9539  0.1253   41.5   43.4   44.5    46.4   \n224             2 -0.7734  53.9427  0.1250   41.5   43.5   44.6    46.4   \n225             2 -0.7973  53.9315  0.1247   41.5   43.5   44.6    46.4   \n226             2 -0.8215  53.9203  0.1244   41.6   43.5   44.6    46.4   \n227             2 -0.8458  53.9090  0.1241   41.6   43.6   44.7    46.4   \n\n           PER_15  PER_25  ...  PER_95  PER_97  PER_99  -3SD  -2SD  -1SD  \\\nAGE_MONTH                  ...                                             \n0             2.9     3.0  ...     4.2     4.3     4.6   2.1   2.5   2.9   \n1             3.9     4.1  ...     5.5     5.7     6.0   2.9   3.4   3.9   \n2             4.9     5.1  ...     6.8     7.0     7.4   3.8   4.3   4.9   \n3             5.6     5.9  ...     7.7     7.9     8.3   4.4   5.0   5.7   \n4             6.2     6.5  ...     8.4     8.6     9.1   4.9   5.6   6.2   \n...           ...     ...  ...     ...     ...     ...   ...   ...   ...   \n223          47.7    49.7  ...    67.5    69.9    75.0  38.7  42.9  47.9   \n224          47.7    49.7  ...    67.5    69.9    75.0  38.8  42.9  47.9   \n225          47.7    49.7  ...    67.5    69.9    75.0  38.9  43.0  47.9   \n226          47.7    49.7  ...    67.5    69.9    75.0  38.9  43.0  47.9   \n227          47.7    49.7  ...    67.5    69.9    75.1  39.0  43.0  47.9   \n\n            0SD  +1SD  +2SD  +3SD  \nAGE_MONTH                          \n0           3.3   3.9   4.4   5.0  \n1           4.5   5.1   5.8   6.6  \n2           5.6   6.3   7.1   8.0  \n3           6.4   7.2   8.0   9.0  \n4           7.0   7.8   8.7   9.7  \n...         ...   ...   ...   ...  \n223        54.0  61.5  71.2  83.9  \n224        53.9  61.5  71.2  84.0  \n225        53.9  61.5  71.2  84.1  \n226        53.9  61.5  71.2  84.2  \n227        53.9  61.5  71.2  84.3  \n\n[456 rows x 24 columns]'

# %%
Z
# Out:
# MONTHS_FROM_BIRTH
# 108    0.602236
# dtype: float64

# %%
# Out:
# array([72.64915252])
